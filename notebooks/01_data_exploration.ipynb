# %%
# Looking into the data to see what we have to work with

import nfl_data_py as nfl
import pandas as pd

years_experiment = list(range(2015, 2025)) 
years = list(range(2015,2026))
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
print([f for f in dir(nfl) if f.startswith('import_')])
# Out:
# ['import_combine_data', 'import_contracts', 'import_depth_charts', 'import_draft_picks', 'import_draft_values', 'import_ftn_data', 'import_ids', 'import_injuries', 'import_ngs_data', 'import_officials', 'import_pbp_data', 'import_players', 'import_qbr', 'import_sc_lines', 'import_schedules', 'import_seasonal_data', 'import_seasonal_pfr', 'import_seasonal_rosters', 'import_snap_counts', 'import_team_desc', 'import_weekly_data', 'import_weekly_pfr', 'import_weekly_rosters', 'import_win_totals']

# %%
teams = nfl.import_team_desc()
print(teams.shape)
teams.info()
teams.head()
# Out:
# (36, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   team_abbr             36 non-null     object
#  1   team_name             36 non-null     object
#  2   team_id               36 non-null     int64
#  3   team_nick             36 non-null     object
#  4   team_conf             36 non-null     object
#  5   team_division         36 non-null     object
#  6   team_color            36 non-null     object
#  7   team_color2           36 non-null     object
#  8   team_color3           34 non-null     object
#  9   team_color4           34 non-null     object
#  10  team_logo_wikipedia   36 non-null     object
#  11  team_logo_espn        36 non-null     object
#  12  team_wordmark         36 non-null     object
#  13  team_conference_logo  36 non-null     object
# ...

# %%
players = nfl.import_players()
print(players.shape)
players.info()
players.head(10)
# Out:
# (25037, 39)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25037 entries, 0 to 25036
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gsis_id                       25037 non-null  object
#  1   display_name                  25037 non-null  object
#  2   common_first_name             25037 non-null  object
#  3   first_name                    25037 non-null  object
#  4   last_name                     25037 non-null  object
#  5   short_name                    8009 non-null   object
#  6   football_name                 8491 non-null   object
#  7   suffix                        164 non-null    object
#  8   esb_id                        25037 non-null  object
#  9   nfl_id                        12099 non-null  object
#  10  pfr_id                        22552 non-null  object
#  11  pff_id                        11251 non-null  object
# ...

# %%
test = nfl.import_depth_charts([2024])
print(test.shape)

depth_charts = nfl.import_depth_charts(years)
print(depth_charts.shape)
depth_charts.info()
depth_charts.head(10)
# Out:
# (37312, 15)
# (923447, 26)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 923447 entries, 0 to 554214
# Data columns (total 26 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   season          369232 non-null  float64
#  1   club_code       369232 non-null  object
#  2   week            366834 non-null  float64
#  3   game_type       369232 non-null  object
#  4   depth_team      369232 non-null  object
#  5   last_name       369232 non-null  object
#  6   first_name      369232 non-null  object
#  7   football_name   369232 non-null  object
#  8   formation       369232 non-null  object
#  9   gsis_id         917870 non-null  object
#  10  jersey_number   369232 non-null  object
#  11  position        369232 non-null  object
#  12  elias_id        369176 non-null  object
#  13  depth_position  369232 non-null  object
#  14  full_name       369232 non-null  object
#  15  dt              554215 non-null  object
# ...

# %%
injuries = nfl.import_injuries(years_experiment)
print(injuries.shape)
injuries.info()
injuries.head(10)
# Out:
# (54720, 16)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54720 entries, 0 to 6214
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   season                     54720 non-null  float64
#  1   game_type                  54720 non-null  object
#  2   team                       54720 non-null  object
#  3   week                       54720 non-null  float64
#  4   gsis_id                    54720 non-null  object
#  5   position                   54720 non-null  object
#  6   full_name                  54720 non-null  object
#  7   first_name                 54720 non-null  object
#  8   last_name                  54720 non-null  object
#  9   report_primary_injury      29098 non-null  object
#  10  report_secondary_injury    1906 non-null   object
#  11  report_status              29104 non-null  object
#  12  practice_primary_injury    54500 non-null  object
# ...

# %%
#Trying to understand why depth charts has so many nulls that dont add up

for year in [2015, 2018, 2021, 2024, 2025, 2026]:
    test = nfl.import_depth_charts([year])
    print(year, test.shape)
    print(test.columns[test.notna().any()].tolist())
    print('---')
# Out:
# 2015 (37058, 15)
# ['season', 'club_code', 'week', 'game_type', 'depth_team', 'last_name', 'first_name', 'football_name', 'formation', 'gsis_id', 'jersey_number', 'position', 'elias_id', 'depth_position', 'full_name']
# ---
# 2018 (36560, 15)
# ['season', 'club_code', 'week', 'game_type', 'depth_team', 'last_name', 'first_name', 'football_name', 'formation', 'gsis_id', 'jersey_number', 'position', 'elias_id', 'depth_position', 'full_name']
# ---
# 2021 (37487, 15)
# ['season', 'club_code', 'week', 'game_type', 'depth_team', 'last_name', 'first_name', 'football_name', 'formation', 'gsis_id', 'jersey_number', 'position', 'elias_id', 'depth_position', 'full_name']
# ---
# 2024 (37312, 15)
# ['season', 'club_code', 'week', 'game_type', 'depth_team', 'last_name', 'first_name', 'football_name', 'formation', 'gsis_id', 'jersey_number', 'position', 'elias_id', 'depth_position', 'full_name']
# ---
# 2025 (554215, 12)
# ...

# %%
weekly_ids = set(weekly['player_id'].unique())
player_ids = set(players['gsis_id'].unique())

overlap = weekly_ids & player_ids
print(f"Unique IDs in weekly: {len(weekly_ids)}")
print(f"Unique IDs in players: {len(player_ids)}")
print(f"Overlapping IDs: {len(overlap)}")
# Out:
# Unique IDs in weekly: 1978
# Unique IDs in players: 25037
# Overlapping IDs: 1978
